# %%
#Importamos librerías requeridas

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Data frame del 2021 (Se eliminaron las filas que contenían solo valores nulos e impedían la salida de los índices)

df_vistazo= pd.read_excel('Gastos y costos 20-23.xlsx', sheet_name='2021', skiprows = 3)
df_vistazo
# Out:
#           FECHA                   FOLIO                                  UUID  \
# 0    2021-01-01  0001010100750847116902  71B4C8B9-8DAA-47CC-AD47-9DD90AA5AF6B
# 1    2021-01-01  0001010100752163714102  B8AEDE83-CC76-404C-A611-6B5A87BA561F
# 2    2021-01-01                   19788  19B9B2C2-DF58-E24D-B43A-3FC4D5A929E7
# 3    2021-01-01                  211781  EAB26414-DD9A-4E8F-9F5C-05FE24D98E48
# 4    2021-01-01                  211782  C16F79B5-FB35-4BFC-AF84-708B24F500BB
# ...         ...                     ...                                   ...
# 3030 2021-12-01                  127043  83F82167-0D14-144E-9D76-045C95F25DDD
# 3031 2021-12-01                   11740  B1C60AE0-02BC-4A33-9513-A280F72B5D06
# 3032 2021-12-01              1092957089  255F4A25-5753-4208-8F6B-0B59E5AE4741
# 3033 2021-12-01                  747826  D8226E4F-9241-44C3-86A4-CDE9BC932528
# 3034 2021-12-01                 1227374  41770F35-39EF-41A4-8DF4-EE9586CF4549
#
# ...

# %%
#Verificamos información del DataFrame
df_vistazo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3035 entries, 0 to 3034
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   FECHA        3035 non-null   datetime64[ns]
#  1   FOLIO        2888 non-null   object
#  2   UUID         3035 non-null   object
#  3   RFC          3035 non-null   object
#  4   PROVEEDOR    3035 non-null   object
#  5   TIPO GASTO   3035 non-null   object
#  6   DESCRIPCION  3035 non-null   object
#  7   MP           2381 non-null   object
#  8   TC           3035 non-null   float64
#  9   IMPORTE      3035 non-null   float64
#  10  IVA          3035 non-null   float64
#  11  RET ISR      3035 non-null   float64
#  12  RET IVA      3035 non-null   float64
#  13  TOTAL MX     3035 non-null   float64
#  14  TOTAL SAT    3035 non-null   float64
#  15  TIPO         3035 non-null   object
#  16  STATUS       3035 non-null   object
#  17  POLIZA       663 non-null    object
# ...

# %%
# Se identifican los valores nulos
valores_nulos=df_vistazo.isnull().sum()
valores_nulos
# Out:
# FECHA             0
# FOLIO           147
# UUID              0
# RFC               0
# PROVEEDOR         0
# TIPO GASTO        0
# DESCRIPCION       0
# MP              654
# TC                0
# IMPORTE           0
# IVA               0
# RET ISR           0
# RET IVA           0
# TOTAL MX          0
# TOTAL SAT         0
# TIPO              0
# STATUS            0
# POLIZA         2372
# dtype: int64

# %%
#Analizar categorias de columnas con ceros

df_vistazo.groupby(['RET IVA'])['RET IVA'].count()
df_vistazo.groupby(['RET ISR'])['RET ISR'].count()
# Out:
# RET ISR
# 0.00       2979
# 157.34        1
# 500.00       11
# 666.00       12
# 1000.00       2
# 1600.00       1
# 2600.00       5
# 2800.00       5
# 3000.00      19
# Name: RET ISR, dtype: int64

# %%
# Eliminamos la columna de Poliza ya que la mayoría de datos son faltantes y no hay un patrón identificable para rellenar
# Se eliminan las variables de ISR y de IVA ya que la mayoría son ceros representando más del 90% de los datos.

df_vistazo2= df_vistazo.drop(['POLIZA','RET IVA','RET ISR'], axis=1)
df_vistazo2
# Out:
#           FECHA                   FOLIO                                  UUID  \
# 0    2021-01-01  0001010100750847116902  71B4C8B9-8DAA-47CC-AD47-9DD90AA5AF6B
# 1    2021-01-01  0001010100752163714102  B8AEDE83-CC76-404C-A611-6B5A87BA561F
# 2    2021-01-01                   19788  19B9B2C2-DF58-E24D-B43A-3FC4D5A929E7
# 3    2021-01-01                  211781  EAB26414-DD9A-4E8F-9F5C-05FE24D98E48
# 4    2021-01-01                  211782  C16F79B5-FB35-4BFC-AF84-708B24F500BB
# ...         ...                     ...                                   ...
# 3030 2021-12-01                  127043  83F82167-0D14-144E-9D76-045C95F25DDD
# 3031 2021-12-01                   11740  B1C60AE0-02BC-4A33-9513-A280F72B5D06
# 3032 2021-12-01              1092957089  255F4A25-5753-4208-8F6B-0B59E5AE4741
# 3033 2021-12-01                  747826  D8226E4F-9241-44C3-86A4-CDE9BC932528
# 3034 2021-12-01                 1227374  41770F35-39EF-41A4-8DF4-EE9586CF4549
#
# ...

# %%
# Se sustituyó el folio por un registro único de identificación para tener un Data Frame Limpio al comenzar la observación de Outliers

df_vistazo2["FOLIO"] = df_vistazo2["FOLIO"].fillna("10000000000")
df_vistazo2
# Out:
#           FECHA                   FOLIO                                  UUID  \
# 0    2021-01-01  0001010100750847116902  71B4C8B9-8DAA-47CC-AD47-9DD90AA5AF6B
# 1    2021-01-01  0001010100752163714102  B8AEDE83-CC76-404C-A611-6B5A87BA561F
# 2    2021-01-01                   19788  19B9B2C2-DF58-E24D-B43A-3FC4D5A929E7
# 3    2021-01-01                  211781  EAB26414-DD9A-4E8F-9F5C-05FE24D98E48
# 4    2021-01-01                  211782  C16F79B5-FB35-4BFC-AF84-708B24F500BB
# ...         ...                     ...                                   ...
# 3030 2021-12-01                  127043  83F82167-0D14-144E-9D76-045C95F25DDD
# 3031 2021-12-01                   11740  B1C60AE0-02BC-4A33-9513-A280F72B5D06
# 3032 2021-12-01              1092957089  255F4A25-5753-4208-8F6B-0B59E5AE4741
# 3033 2021-12-01                  747826  D8226E4F-9241-44C3-86A4-CDE9BC932528
# 3034 2021-12-01                 1227374  41770F35-39EF-41A4-8DF4-EE9586CF4549
#
# ...

# %%
# Se identifican los valores nulos
valores_nulos2=df_vistazo2.isnull().sum()
valores_nulos2

# La variable llamada "MP" contiene datos puramente cualitativos por lo que se le realizará un filtro para solo tener variables cuantitativas para trabajar outliers
# Out:
# FECHA            0
# FOLIO            0
# UUID             0
# RFC              0
# PROVEEDOR        0
# TIPO GASTO       0
# DESCRIPCION      0
# MP             654
# TC               0
# IMPORTE          0
# IVA              0
# TOTAL MX         0
# TOTAL SAT        0
# TIPO             0
# STATUS           0
# dtype: int64

# %%
#Filtro para contar solo con variables cualitativas y excluirlas de los métodos outliers
df_cuali = df_vistazo2.iloc[ : , [0,1,2,3,4,5,6,7,13,14]]
df_cuali
# Out:
#           FECHA                   FOLIO                                  UUID  \
# 0    2021-01-01  0001010100750847116902  71B4C8B9-8DAA-47CC-AD47-9DD90AA5AF6B
# 1    2021-01-01  0001010100752163714102  B8AEDE83-CC76-404C-A611-6B5A87BA561F
# 2    2021-01-01                   19788  19B9B2C2-DF58-E24D-B43A-3FC4D5A929E7
# 3    2021-01-01                  211781  EAB26414-DD9A-4E8F-9F5C-05FE24D98E48
# 4    2021-01-01                  211782  C16F79B5-FB35-4BFC-AF84-708B24F500BB
# ...         ...                     ...                                   ...
# 3030 2021-12-01                  127043  83F82167-0D14-144E-9D76-045C95F25DDD
# 3031 2021-12-01                   11740  B1C60AE0-02BC-4A33-9513-A280F72B5D06
# 3032 2021-12-01              1092957089  255F4A25-5753-4208-8F6B-0B59E5AE4741
# 3033 2021-12-01                  747826  D8226E4F-9241-44C3-86A4-CDE9BC932528
# 3034 2021-12-01                 1227374  41770F35-39EF-41A4-8DF4-EE9586CF4549
#
# ...

# %%
# Filtro para solo contar con variables cuantitativas
df_cuanti= df_vistazo2.drop(['FECHA','FOLIO','UUID','RFC','PROVEEDOR','TIPO GASTO','DESCRIPCION','MP','TIPO','STATUS'], axis=1)
df_cuanti
# Out:
#        TC   IMPORTE     IVA  TOTAL MX  TOTAL SAT
# 0     1.0    490.00   78.40    568.40     568.40
# 1     1.0    345.00   55.20    400.20     400.20
# 2     1.0   3447.41  551.59   3999.00    3999.00
# 3     1.0   5551.38  888.22   6439.60    6439.60
# 4     1.0   5551.98  888.32   6440.30    6440.30
# ...   ...       ...     ...       ...        ...
# 3030  1.0      0.00    0.00      0.00       0.00
# 3031  1.0      0.00    0.00      0.00       0.00
# 3032  1.0  22826.46  705.58  23532.04   23532.04
# 3033  1.0      0.00    0.00      0.00       0.00
# 3034  1.0  15656.15    0.00  15656.15   15656.15
#
# [3035 rows x 5 columns]

# %%
# Se identifican los valores nulos de las variables cuantitativas
valores_nulos3=df_cuanti.isnull().sum()
valores_nulos3
# Out:
# TC           0
# IMPORTE      0
# IVA          0
# TOTAL MX     0
# TOTAL SAT    0
# dtype: int64

# %%
#Realizamos diagrama de caja o bigote de cada columna del dataframe
fig = plt.figure(figsize =(15, 8))
df_cuanti.plot(kind='box', vert=False)
plt.title("Valores Atípicos del Dataframe")
plt.show() # Se dibuja el diagrama

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y = df_cuanti

percentile25 = y.quantile(0.25) #Q1
percentile75 = y.quantile(0.75) #Q3
iqr = percentile75 - percentile25

Limite_Superior_iqr = percentile75 + 1.5*iqr
Limite_Inferior_iqr = percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido TC               1.0000
# IMPORTE      10127.7125
# IVA           1381.4750
# TOTAL MX     11580.2750
# TOTAL SAT    11456.0225
# dtype: float64
# Limite inferior permitido TC              1.0000
# IMPORTE     -6076.6275
# IVA          -828.8850
# TOTAL MX    -6948.1650
# TOTAL SAT   -6818.3175
# dtype: float64

# %%
#Encontramos Outliers del Dataframe

outliers_iqr= df_cuanti[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#       TC   IMPORTE  IVA  TOTAL MX  TOTAL SAT
# 0    NaN       NaN  NaN       NaN        NaN
# 1    NaN       NaN  NaN       NaN        NaN
# 2    NaN       NaN  NaN       NaN        NaN
# 3    NaN       NaN  NaN       NaN        NaN
# 4    NaN       NaN  NaN       NaN        NaN
# ...   ..       ...  ...       ...        ...
# 3030 NaN       NaN  NaN       NaN        NaN
# 3031 NaN       NaN  NaN       NaN        NaN
# 3032 NaN  22826.46  NaN  23532.04   23532.04
# 3033 NaN       NaN  NaN       NaN        NaN
# 3034 NaN  15656.15  NaN  15656.15   15656.15
#
# [3035 rows x 5 columns]

# %%
#Obtenemos datos limpios del Dataframe
data3_iqr= df_cuanti[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
data3_iqr
# Out:
#        TC  IMPORTE     IVA  TOTAL MX  TOTAL SAT
# 0     1.0   490.00   78.40     568.4      568.4
# 1     1.0   345.00   55.20     400.2      400.2
# 2     1.0  3447.41  551.59    3999.0     3999.0
# 3     1.0  5551.38  888.22    6439.6     6439.6
# 4     1.0  5551.98  888.32    6440.3     6440.3
# ...   ...      ...     ...       ...        ...
# 3030  1.0     0.00    0.00       0.0        0.0
# 3031  1.0     0.00    0.00       0.0        0.0
# 3032  1.0      NaN  705.58       NaN        NaN
# 3033  1.0     0.00    0.00       0.0        0.0
# 3034  1.0      NaN    0.00       NaN        NaN
#
# [3035 rows x 5 columns]

# %%
# Se corroboran los valores nulos del dataframe LIMPIO
valores_nulos=data3_iqr.isnull().sum()
valores_nulos
# Out:
# TC            24
# IMPORTE      336
# IVA          342
# TOTAL MX     347
# TOTAL SAT    351
# dtype: int64

# %%
#Realizamos una copia del dataframe
data4_iqr = data3_iqr.copy()
data4_iqr
# Out:
#        TC  IMPORTE     IVA  TOTAL MX  TOTAL SAT
# 0     1.0   490.00   78.40     568.4      568.4
# 1     1.0   345.00   55.20     400.2      400.2
# 2     1.0  3447.41  551.59    3999.0     3999.0
# 3     1.0  5551.38  888.22    6439.6     6439.6
# 4     1.0  5551.98  888.32    6440.3     6440.3
# ...   ...      ...     ...       ...        ...
# 3030  1.0     0.00    0.00       0.0        0.0
# 3031  1.0     0.00    0.00       0.0        0.0
# 3032  1.0      NaN  705.58       NaN        NaN
# 3033  1.0     0.00    0.00       0.0        0.0
# 3034  1.0      NaN    0.00       NaN        NaN
#
# [3035 rows x 5 columns]

# %%
#Reemplazamos valores atípicos (nulos) del dataframe con "median" para la variable de "TC" ya que la mayoría de datos tienen un mismo valor

data4_iqr["TC"]= data4_iqr["TC"].fillna(round(data3_iqr["TC"].median(),1))

# Reemplazamos valores atípicos (nulos) del dataframe con "mean" para las variables enteramente monetarias para no desvirtuar el resultado de los outliers

data4_iqr["IMPORTE"]= data4_iqr["IMPORTE"].fillna(round(data3_iqr["IMPORTE"].mean(),1))
data4_iqr["IVA"]= data4_iqr["IVA"].fillna(round(data3_iqr["IVA"].mean(),1))
data4_iqr["TOTAL MX"]= data4_iqr["TOTAL MX"].fillna(round(data3_iqr["TOTAL MX"].mean(),1))
data4_iqr["TOTAL SAT"]= data4_iqr["TOTAL SAT"].fillna(round(data3_iqr["TOTAL SAT"].mean(),1))

# %%
# Se identifican los valores nulos de las variables cuantitativas
valores_nulos4=data4_iqr.isnull().sum()
valores_nulos4
# Out:
# TC           0
# IMPORTE      0
# IVA          0
# TOTAL MX     0
# TOTAL SAT    0
# dtype: int64

# %%
# Unimos las variables cualitativas a las cuantitativas con el dataframe

Datos_limpios = pd.concat([df_cuali, data4_iqr], axis=1)
Datos_limpios
# Out:
#           FECHA                   FOLIO                                  UUID  \
# 0    2021-01-01  0001010100750847116902  71B4C8B9-8DAA-47CC-AD47-9DD90AA5AF6B
# 1    2021-01-01  0001010100752163714102  B8AEDE83-CC76-404C-A611-6B5A87BA561F
# 2    2021-01-01                   19788  19B9B2C2-DF58-E24D-B43A-3FC4D5A929E7
# 3    2021-01-01                  211781  EAB26414-DD9A-4E8F-9F5C-05FE24D98E48
# 4    2021-01-01                  211782  C16F79B5-FB35-4BFC-AF84-708B24F500BB
# ...         ...                     ...                                   ...
# 3030 2021-12-01                  127043  83F82167-0D14-144E-9D76-045C95F25DDD
# 3031 2021-12-01                   11740  B1C60AE0-02BC-4A33-9513-A280F72B5D06
# 3032 2021-12-01              1092957089  255F4A25-5753-4208-8F6B-0B59E5AE4741
# 3033 2021-12-01                  747826  D8226E4F-9241-44C3-86A4-CDE9BC932528
# 3034 2021-12-01                 1227374  41770F35-39EF-41A4-8DF4-EE9586CF4549
#
# ...

# %%
# Verificación de los valores nulos del dataframe LIMPIO
valores_nulos_casi=Datos_limpios.isnull().sum()
valores_nulos_casi
# Out:
# FECHA            0
# FOLIO            0
# UUID             0
# RFC              0
# PROVEEDOR        0
# TIPO GASTO       0
# DESCRIPCION      0
# MP             654
# TIPO             0
# STATUS           0
# TC               0
# IMPORTE          0
# IVA              0
# TOTAL MX         0
# TOTAL SAT        0
# dtype: int64

# %%
# La variable de "MP" pertenece a 2 categorías diferentes, el llenado se realizará con otro string e identificador de desconocido

Datos_limpios["MP"] =Datos_limpios["MP"].fillna("Desconocido")

# %%
# Verificación de los valores nulos del dataframe LIMPIO
valores_nulos_Final=Datos_limpios.isnull().sum()
valores_nulos_Final
# Out:
# FECHA          0
# FOLIO          0
# UUID           0
# RFC            0
# PROVEEDOR      0
# TIPO GASTO     0
# DESCRIPCION    0
# MP             0
# TIPO           0
# STATUS         0
# TC             0
# IMPORTE        0
# IVA            0
# TOTAL MX       0
# TOTAL SAT      0
# dtype: int64

# %%
#Convertir DataFrame a CSV
Datos_limpios.to_csv("Datos_limpios_2021.csv")
